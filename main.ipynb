# %%
import cv2
import mediapipe as mp

mp_face_mesh = mp.solutions.face_mesh
mp_drawing = mp.solutions.drawing_utils

cap = cv2.VideoCapture(0, cv2.CAP_DSHOW)

# Función para aplicar la detección de malla facial
def process_frame(frame, face_mesh):
    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    results = face_mesh.process(frame_rgb)

    if results.multi_face_landmarks is not None:
        for face_landmarks in results.multi_face_landmarks:
            # Dibujar la malla facial completa
            mp_drawing.draw_landmarks(
                frame, face_landmarks,
                mp_face_mesh.FACEMESH_TESSELATION,
                mp_drawing.DrawingSpec(color=(0, 255, 255), thickness=1, circle_radius=1),
                mp_drawing.DrawingSpec(color=(255, 0, 255), thickness=1)
            )
            # Dibujar puntos específicos
            points = [127, 356, 183, 332, 0, 17, 468, 473]
            for point in points:
                if point < len(face_landmarks.landmark):  # Verificar índice válido
                    x = int(face_landmarks.landmark[point].x * frame.shape[1])
                    y = int(face_landmarks.landmark[point].y * frame.shape[0])
                    cv2.circle(frame, (x, y), 2, (0, 255, 0), -1)
    
    # Devolver el frame con los puntos dibujados
    return frame

# %%
def filtro_1(frame):
    print("Modo 1")
    with mp_face_mesh.FaceMesh(
            static_image_mode=False,
            max_num_faces=1,
            min_detection_confidence=0.5) as face_mesh:
        return process_frame(frame, face_mesh)

def filtro_2(frame):
    print("Modo 2")
    with mp_face_mesh.FaceMesh(
            static_image_mode=False,
            max_num_faces=1,
            min_detection_confidence=0.5) as face_mesh:
        return process_frame(frame, face_mesh)

def process_frame(frame, mode):
    if mode == 1: frame = filtro_1(frame)
    elif mode == 2: frame = filtro_2(frame)
    return frame

def main():
    cap = cv2.VideoCapture(0)  # Abrir la cámara
    mode = 1                   # Modo inicial
    cap.set(cv2.CAP_PROP_FRAME_WIDTH, 1280)
            
    if not cap.isOpened():
        print("No se puede abrir la cámara")
        exit()

    while True:
        ret, frame = cap.read()
        
        if not ret:
            break
        
        frame = process_frame(frame, mode)
        # Muestrar el frame
        cv2.imshow('Frame', frame) 

        key = cv2.waitKey(1) & 0xFF
        if key == ord('1'): mode = 1
        elif key == ord('2'): mode = 2
        elif key == ord('q'): break
        
        process_frame(frame, mode)
        
    cap.release()
    cv2.destroyAllWindows()

if __name__ == '__main__':
    main()
# Out:
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 1
# Modo 2
# Modo 2
# Modo 2
# Modo 2
# Modo 2
# Modo 2
# ...
